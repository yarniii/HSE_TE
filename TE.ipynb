# %% [markdown]
# # Тестовое задание Junior Data Analyst

# %% [markdown]
# ## Часть 1. Работа с данными
#
# Входные данные для тестового задания можно найти <a href="https://docs.google.com/spreadsheets/d/165sp-lWd1L4qWxggw25DJo_njOCvzdUjAd414NSE8co/edit?usp=sharing">здесь</a>.
# Ваша задача - подготовить и обработать исходные данных так, чтобы их можно было использовать во второй части задания.
#
# Требования к выходным данным:
#     1) В выходной таблице должны остаться только следующие колонки:
# area, cluster, cluster_name, keyword, x, y, count, color, где
#  * area - область,
#  * cluster - номер кластера,
#  * cluster_name - название кластера,
#  * keyword - словосочетание,
#  * count - показатель,
#  * x и y - координаты для диаграммы рассеяния,
#  * color - цвет точки на карте для данного словосочетания

# %%
import pandas as pd # импортируем библиотеку пандас
import seaborn as sns
import matplotlib.pyplot as plt
import random 
import plotly_express as px
import plotly.io as pio
import plotly.graph_objects as go
from openpyxl import load_workbook


pio.renderers.default='notebook'

# %%
# загружаем данные из гугл таблицы
data=pd.read_csv("https://docs.google.com/spreadsheets/d/165sp-lWd1L4qWxggw25DJo_njOCvzdUjAd414NSE8co/gviz/tq?tqx=out:csv")

# %%
data.head() # выводим первые 5 строк
# Out:
#           area  cluster cluster_name                     keyword  good (1)  \
# 0  eligibility        0    Кластер 0     several animated buried       1.0
# 1  eligibility        0    Кластер 0      singles unusual buyers       1.0
# 2  eligibility        0    Кластер 0          hawaiian directive       1.0
# 3  eligibility        0    Кластер 0           dynamics directly       1.0
# 4  eligibility        1    Кластер 1  decision surgeons montreal       1.0
#
#     count          x                   y
# 0  1260.0   5.772342  12.564796257345005
# 1   866.0  14.829280  7.8507285727125815
# 2   163.0  11.381856  3.8981370219558604
# 3  1146.0   9.980149   6.281427914064545
# 4   823.0   3.283940    4.39674063521296

# %%
data.shape
# Out:
# (228, 8)

# %%
data.dtypes
# Out:
# area             object
# cluster           int64
# cluster_name     object
# keyword          object
# good (1)        float64
# count           float64
# x               float64
# y                object
# dtype: object

# %%
data.y=data.y.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 data.y=data.y.astype(float)
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/internals/managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/internals/managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/internals/blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/my_project_dir/my_project_env/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '0x414fe002'

# %%
data.loc[data.y=='0x414fe002']
# Out:
#       area  cluster cluster_name                                  keyword  \
# 99  worlds        2    Кластер 2  applicants vacuum distance restrictions
#
#     good (1)   count          x           y
# 99       1.0  1785.0  11.916011  0x414fe002

# %%
data.drop(99,inplace=True)

# %%
data.y=data.y.astype(float)

# %%
data.drop(columns='good (1)',inplace=True) # удаляем лишнюю колонку

# %%
data.head()
# Out:
#           area  cluster cluster_name                     keyword   count  \
# 0  eligibility        0    Кластер 0     several animated buried  1260.0
# 1  eligibility        0    Кластер 0      singles unusual buyers   866.0
# 2  eligibility        0    Кластер 0          hawaiian directive   163.0
# 3  eligibility        0    Кластер 0           dynamics directly  1146.0
# 4  eligibility        1    Кластер 1  decision surgeons montreal   823.0
#
#            x          y
# 0   5.772342  12.564796
# 1  14.829280   7.850729
# 2  11.381856   3.898137
# 3   9.980149   6.281428
# 4   3.283940   4.396741

# %%
data.dropna(inplace=True) # удаляем пустые значения

# %%
data.shape
# Out:
# (224, 7)

# %% [markdown]
# # Работа с колонкой color
#  Колонку color нужно добавить самостоятельно - цвета вы можете взять из цветовых палеток Tableu или по своему усмотрению.<br>
#     3) Цвет задается каждому словосочетанию согласно следующими правилам:
# * внутри одной области цвета словосочетаний в одном кластере должны быть одинаковые, в разных - отличаться (например, у "Кластер 1" все слова будут окрашены в красный, у "Кластер 2" - в зеленый и т.д.)
# * цвета кластеров в разных областях могут повторяться
# * цвета кластеров в разных областях с разным номером не имеют никакой связи (у одной области [area] слова из "Кластер 1" могут быть красного цвета, в другой области у слов из "Кластер 1" может быть другой цвет)

# %%
data["color"]=0

# %%
palette=sns.color_palette(palette="tab10").as_hex() # цветовая палитра

# %%
palette[0]
# Out:
# '#1f77b4'

# %% [markdown]
# ### внутри одной области цвета словосочетаний в одном кластере должны быть одинаковые, в разных - отличаться (например, у "Кластер 1" все слова будут окрашены в красный, у "Кластер 2" - в зеленый и т.д.)

# %%
areas=data.area.unique() # cписок наших областей

# %%
areas
# Out:
# array(['eligibility', 'capability', 'available', 'protein', 'winner',
#        'locator', 'worlds', 'ar\\vr', 'twisted', 'lithuania', 'personnel',
#        'housewives', 'dialog', 'except', 'greetings'], dtype=object)

# %%
clusters=data.cluster.unique() # список кластеров

# %%
clusters
# Out:
# array([0, 1, 2, 3])

# %%
data
# Out:
#             area  cluster cluster_name                     keyword   count  \
# 0    eligibility        0    Кластер 0     several animated buried  1260.0
# 1    eligibility        0    Кластер 0      singles unusual buyers   866.0
# 2    eligibility        0    Кластер 0          hawaiian directive   163.0
# 3    eligibility        0    Кластер 0           dynamics directly  1146.0
# 4    eligibility        1    Кластер 1  decision surgeons montreal   823.0
# ..           ...      ...          ...                         ...     ...
# 223    greetings        2    Кластер 2          disposition layout   279.0
# 224    greetings        2    Кластер 2            sapphire grounds   335.0
# 225    greetings        3    Кластер 3     entire ethical speakers  1782.0
# 226    greetings        3    Кластер 3  courtesy textiles diameter    84.0
# 227    greetings        3    Кластер 3              comfort rivers  1806.0
#
#              x          y  color
# 0     5.772342  12.564796      0
# 1    14.829280   7.850729      0
# 2    11.381856   3.898137      0
# 3     9.980149   6.281428      0
# 4     3.283940   4.396741      0
# ..         ...        ...    ...
# 223  10.971214   4.857810      0
# 224   1.160626   3.642820      0
# 225   7.985910   6.003699      0
# 226   0.509490   4.151199      0
# 227   6.961866   6.435590      0
#
# [224 rows x 8 columns]

# %%
for area in areas: # проход по областям
    random.shuffle(palette) # перемешиваем список цветов
    for cluster, color in zip(clusters,palette): # используем zip чтобы для каждого кластера был свой цвет
            data.loc[(data['area']==area) & (data['cluster']==clusters[cluster]),'color']=palette[cluster]

# %%
data
# Out:
#             area  cluster cluster_name                     keyword   count  \
# 0    eligibility        0    Кластер 0     several animated buried  1260.0
# 1    eligibility        0    Кластер 0      singles unusual buyers   866.0
# 2    eligibility        0    Кластер 0          hawaiian directive   163.0
# 3    eligibility        0    Кластер 0           dynamics directly  1146.0
# 4    eligibility        1    Кластер 1  decision surgeons montreal   823.0
# ..           ...      ...          ...                         ...     ...
# 223    greetings        2    Кластер 2          disposition layout   279.0
# 224    greetings        2    Кластер 2            sapphire grounds   335.0
# 225    greetings        3    Кластер 3     entire ethical speakers  1782.0
# 226    greetings        3    Кластер 3  courtesy textiles diameter    84.0
# 227    greetings        3    Кластер 3              comfort rivers  1806.0
#
#              x          y    color
# 0     5.772342  12.564796  #2ca02c
# 1    14.829280   7.850729  #2ca02c
# 2    11.381856   3.898137  #2ca02c
# 3     9.980149   6.281428  #2ca02c
# 4     3.283940   4.396741  #bcbd22
# ..         ...        ...      ...
# 223  10.971214   4.857810  #ff7f0e
# 224   1.160626   3.642820  #ff7f0e
# 225   7.985910   6.003699  #1f77b4
# 226   0.509490   4.151199  #1f77b4
# 227   6.961866   6.435590  #1f77b4
#
# [224 rows x 8 columns]

# %% [markdown]
# #  Не должно быть дубликатов слов в одной и той же области (area), но словосочетание может повторяться из area в area

# %%
#группируем наши данные по областям. Находим количество уникальных значений и общее количество

dublicates=data\
    .groupby('area',as_index=False)\
    .agg({'keyword':[pd.Series.nunique,'count']})

# %%
dublicates
# Out:
#            area keyword
#                 nunique count
# 0         ar\vr      14    15
# 1     available      15    15
# 2    capability      15    15
# 3        dialog      14    15
# 4   eligibility      14    16
# 5        except      15    15
# 6     greetings      14    15
# 7    housewives      14    14
# 8     lithuania      15    15
# 9       locator      15    15
# 10    personnel      15    15
# 11      protein      14    14
# 12      twisted      14    16
# 13       winner      15    15
# 14       worlds      14    14

# %%
dublicates['dublicat']=dublicates['keyword']['count']-dublicates['keyword']['nunique'] # подсчитываем количество дубликатом

# %%
dublicates.sort_values('dublicat',ascending=False)
# Out:
#            area keyword       dublicat
#                 nunique count
# 4   eligibility      14    16        2
# 12      twisted      14    16        2
# 0         ar\vr      14    15        1
# 3        dialog      14    15        1
# 6     greetings      14    15        1
# 1     available      15    15        0
# 2    capability      15    15        0
# 5        except      15    15        0
# 7    housewives      14    14        0
# 8     lithuania      15    15        0
# 9       locator      15    15        0
# 10    personnel      15    15        0
# 11      protein      14    14        0
# 13       winner      15    15        0
# 14       worlds      14    14        0

# %%
areas_with_dublicates=dublicates.loc[dublicates.dublicat>0].area.to_list() # создаем список областей с дубликатами

# %%
areas_with_dublicates
# Out:
# ['ar\\vr', 'dialog', 'eligibility', 'greetings', 'twisted']

# %%
data.shape
# Out:
# (224, 8)

# %%
for i in areas_with_dublicates: # проходимя по списку и дропаем дабликаты
    data.loc[data.area==i]=data.loc[data.area==i].drop_duplicates(subset='keyword')

# %%
data.shape
# Out:
# (224, 8)

# %%
data.sort_values('area',ascending=True)
# Out:
#       area  cluster cluster_name                             keyword   count  \
# 112  ar\vr      1.0    Кластер 1                     michael tobacco  1007.0
# 108  ar\vr      0.0    Кластер 0                reservations linking   751.0
# 109  ar\vr      0.0    Кластер 0                 committees parallel   173.0
# 110  ar\vr      1.0    Кластер 1  postcards looked republic detector  1397.0
# 111  ar\vr      1.0    Кластер 1        filling volunteers academics   773.0
# ..     ...      ...          ...                                 ...     ...
# 117    NaN      NaN          NaN                                 NaN     NaN
# 125    NaN      NaN          NaN                                 NaN     NaN
# 135    NaN      NaN          NaN                                 NaN     NaN
# 194    NaN      NaN          NaN                                 NaN     NaN
# 220    NaN      NaN          NaN                                 NaN     NaN
#
#              x          y    color
# 112   6.210880  12.721264  #1f77b4
# 108  10.195602  12.259496  #2ca02c
# 109   6.735260   3.613983  #2ca02c
# 110  10.474474   6.220012  #1f77b4
# 111  10.833920   8.652737  #1f77b4
# ..         ...        ...      ...
# 117        NaN        NaN      NaN
# 125        NaN        NaN      NaN
# 135        NaN        NaN      NaN
# 194        NaN        NaN      NaN
# 220        NaN        NaN      NaN
#
# [224 rows x 8 columns]

# %%
data.dropna(inplace=True)

# %%
# проверка
data\
    .groupby('area',as_index=False)\
    .agg({'keyword':[pd.Series.nunique,'count']})
# Out:
#            area keyword
#                 nunique count
# 0         ar\vr      14    14
# 1     available      15    15
# 2    capability      15    15
# 3        dialog      14    14
# 4   eligibility      14    14
# 5        except      15    15
# 6     greetings      14    14
# 7    housewives      14    14
# 8     lithuania      15    15
# 9       locator      15    15
# 10    personnel      15    15
# 11      protein      14    14
# 12      twisted      14    14
# 13       winner      15    15
# 14       worlds      14    14

# %% [markdown]
# #     4) Колонки должны называться именно так, как указано в п.1

# %%
tempdata=data.copy()

# %%
tempdata
# Out:
#             area  cluster cluster_name                     keyword   count  \
# 0    eligibility      0.0    Кластер 0     several animated buried  1260.0
# 1    eligibility      0.0    Кластер 0      singles unusual buyers   866.0
# 2    eligibility      0.0    Кластер 0          hawaiian directive   163.0
# 3    eligibility      0.0    Кластер 0           dynamics directly  1146.0
# 4    eligibility      1.0    Кластер 1  decision surgeons montreal   823.0
# ..           ...      ...          ...                         ...     ...
# 223    greetings      2.0    Кластер 2          disposition layout   279.0
# 224    greetings      2.0    Кластер 2            sapphire grounds   335.0
# 225    greetings      3.0    Кластер 3     entire ethical speakers  1782.0
# 226    greetings      3.0    Кластер 3  courtesy textiles diameter    84.0
# 227    greetings      3.0    Кластер 3              comfort rivers  1806.0
#
#              x          y    color
# 0     5.772342  12.564796  #2ca02c
# 1    14.829280   7.850729  #2ca02c
# 2    11.381856   3.898137  #2ca02c
# 3     9.980149   6.281428  #2ca02c
# 4     3.283940   4.396741  #bcbd22
# ..         ...        ...      ...
# 223  10.971214   4.857810  #ff7f0e
# 224   1.160626   3.642820  #ff7f0e
# 225   7.985910   6.003699  #1f77b4
# 226   0.509490   4.151199  #1f77b4
# 227   6.961866   6.435590  #1f77b4
#
# [217 rows x 8 columns]

# %%
tempdata=tempdata.eval('count=@data.x',inplace=False)

# %%
tempdata=tempdata.eval('x=@data.y',inplace=False)

# %%
tempdata=tempdata.eval("y=@data['count']",inplace=False)

# %%
data
# Out:
#             area  cluster cluster_name                     keyword   count  \
# 0    eligibility      0.0    Кластер 0     several animated buried  1260.0
# 1    eligibility      0.0    Кластер 0      singles unusual buyers   866.0
# 2    eligibility      0.0    Кластер 0          hawaiian directive   163.0
# 3    eligibility      0.0    Кластер 0           dynamics directly  1146.0
# 4    eligibility      1.0    Кластер 1  decision surgeons montreal   823.0
# ..           ...      ...          ...                         ...     ...
# 223    greetings      2.0    Кластер 2          disposition layout   279.0
# 224    greetings      2.0    Кластер 2            sapphire grounds   335.0
# 225    greetings      3.0    Кластер 3     entire ethical speakers  1782.0
# 226    greetings      3.0    Кластер 3  courtesy textiles diameter    84.0
# 227    greetings      3.0    Кластер 3              comfort rivers  1806.0
#
#              x          y    color
# 0     5.772342  12.564796  #2ca02c
# 1    14.829280   7.850729  #2ca02c
# 2    11.381856   3.898137  #2ca02c
# 3     9.980149   6.281428  #2ca02c
# 4     3.283940   4.396741  #bcbd22
# ..         ...        ...      ...
# 223  10.971214   4.857810  #ff7f0e
# 224   1.160626   3.642820  #ff7f0e
# 225   7.985910   6.003699  #1f77b4
# 226   0.509490   4.151199  #1f77b4
# 227   6.961866   6.435590  #1f77b4
#
# [217 rows x 8 columns]

# %%
tempdata
# Out:
#             area  cluster cluster_name                     keyword      count  \
# 0    eligibility      0.0    Кластер 0     several animated buried   5.772342
# 1    eligibility      0.0    Кластер 0      singles unusual buyers  14.829280
# 2    eligibility      0.0    Кластер 0          hawaiian directive  11.381856
# 3    eligibility      0.0    Кластер 0           dynamics directly   9.980149
# 4    eligibility      1.0    Кластер 1  decision surgeons montreal   3.283940
# ..           ...      ...          ...                         ...        ...
# 223    greetings      2.0    Кластер 2          disposition layout  10.971214
# 224    greetings      2.0    Кластер 2            sapphire grounds   1.160626
# 225    greetings      3.0    Кластер 3     entire ethical speakers   7.985910
# 226    greetings      3.0    Кластер 3  courtesy textiles diameter   0.509490
# 227    greetings      3.0    Кластер 3              comfort rivers   6.961866
#
#              x       y    color
# 0    12.564796  1260.0  #2ca02c
# 1     7.850729   866.0  #2ca02c
# 2     3.898137   163.0  #2ca02c
# 3     6.281428  1146.0  #2ca02c
# 4     4.396741   823.0  #bcbd22
# ..         ...     ...      ...
# 223   4.857810   279.0  #ff7f0e
# 224   3.642820   335.0  #ff7f0e
# 225   6.003699  1782.0  #1f77b4
# 226   4.151199    84.0  #1f77b4
# 227   6.435590  1806.0  #1f77b4
#
# [217 rows x 8 columns]

# %%
tempdata.rename(columns={'count':'x','x':'y','y':'count'},inplace=True)

# %%
data=tempdata

# %%
data
# Out:
#             area  cluster cluster_name                     keyword          x  \
# 0    eligibility      0.0    Кластер 0     several animated buried   5.772342
# 1    eligibility      0.0    Кластер 0      singles unusual buyers  14.829280
# 2    eligibility      0.0    Кластер 0          hawaiian directive  11.381856
# 3    eligibility      0.0    Кластер 0           dynamics directly   9.980149
# 4    eligibility      1.0    Кластер 1  decision surgeons montreal   3.283940
# ..           ...      ...          ...                         ...        ...
# 223    greetings      2.0    Кластер 2          disposition layout  10.971214
# 224    greetings      2.0    Кластер 2            sapphire grounds   1.160626
# 225    greetings      3.0    Кластер 3     entire ethical speakers   7.985910
# 226    greetings      3.0    Кластер 3  courtesy textiles diameter   0.509490
# 227    greetings      3.0    Кластер 3              comfort rivers   6.961866
#
#              y   count    color
# 0    12.564796  1260.0  #2ca02c
# 1     7.850729   866.0  #2ca02c
# 2     3.898137   163.0  #2ca02c
# 3     6.281428  1146.0  #2ca02c
# 4     4.396741   823.0  #bcbd22
# ..         ...     ...      ...
# 223   4.857810   279.0  #ff7f0e
# 224   3.642820   335.0  #ff7f0e
# 225   6.003699  1782.0  #1f77b4
# 226   4.151199    84.0  #1f77b4
# 227   6.435590  1806.0  #1f77b4
#
# [217 rows x 8 columns]

# %% [markdown]
# #  Сортировка должна происходить по колонкам area, cluster, cluster_name, count (по count значения сортируются в убывающем порядке, в остальных - по возрастающему).

# %%
data=data.sort_values(['area','cluster','cluster_name','count'],ascending=[True,True,True,False])

# %%
data.cluster=data.cluster.astype(int)

# %%
data
# Out:
#        area  cluster cluster_name                             keyword  \
# 106   ar\vr        0    Кластер 0           written conflict fabulous
# 108   ar\vr        0    Кластер 0                reservations linking
# 107   ar\vr        0    Кластер 0                  interfaces neutral
# 109   ar\vr        0    Кластер 0                 committees parallel
# 110   ar\vr        1    Кластер 1  postcards looked republic detector
# ..      ...      ...          ...                                 ...
# 100  worlds        2    Кластер 2                   ringtone parental
# 102  worlds        2    Кластер 2                   recipient traffic
# 105  worlds        3    Кластер 3                   immunology plates
# 103  worlds        3    Кластер 3                     holdings herbal
# 104  worlds        3    Кластер 3                    exchanges castle
#
#              x          y   count    color
# 106   2.991167   7.106799  1443.0  #2ca02c
# 108  10.195602  12.259496   751.0  #2ca02c
# 107  10.443533  13.809915   586.0  #2ca02c
# 109   6.735260   3.613983   173.0  #2ca02c
# 110  10.474474   6.220012  1397.0  #1f77b4
# ..         ...        ...     ...      ...
# 100  11.723895   4.363994   471.0  #2ca02c
# 102   5.593629   0.553368   236.0  #2ca02c
# 105   2.407028   7.651527  1653.0  #17becf
# 103   3.986508  10.906340  1476.0  #17becf
# 104   8.082231   6.587933  1097.0  #17becf
#
# [217 rows x 8 columns]

# %%
data.to_excel("Test_HSE_EX.xlsx",index=False, freeze_panes=(1,0),)

# %%
writer = pd.ExcelWriter('Test_HSE_EX.xlsx', engine='openpyxl')
data.to_excel(writer, 'data', index=False)
ws=writer.sheets['data']

ws.auto_filter.ref='A:H'
writer.save()
# Out:
# /tmp/ipykernel_6161/1248926123.py:6: FutureWarning:
#
# save is not part of the public API, usage can give unexpected results and will be removed in a future version

# %% [markdown]
# # Часть 2. Построение графиков
# На основании обработанных данных постройте по одной диаграмме рассеяния для каждой области (area) (пример внешнего вида см. в приложенном svg-файле).<br>
# Требования к визуализации:<br>
# * Наличие Footer-подписи на изображении
# * Наличие легенды цветов и кластеров
# * Перенос слишком длинных словосочетаний (например, слова длиннее 15 символов, можно разбить на "solar\n cell")
# * Минимизация наложения (слепливания) подписей к друг на друга (постарайтесь сделать так, чтобы наложение было минимальным)
# * Обводка точек.

# %%
def improve_text_position(x):
    """ it is more efficient if the x values are sorted """
    # fix indentation 
    positions = ['top center', 'bottom center']  # you can add more: left center ...
    return [positions[i % len(positions)] for i in range(len(x))]

# %%
def draw_fig(df,i):
    fig=px.scatter(df,x='x',y='y',
               text='keyword',
               color='cluster_name',
               labels='cluster_name',
               size='count',
               color_discrete_sequence=list(df.color.unique()),
               height=1500,width=1500,
               
              render_mode='svg')
    fig.update_traces(line=dict(color="Black", width=0.5))
    fig.update_layout(xaxis_title=f"{i}'s  clusters",
                  yaxis_title=" ",
                legend_title="Кластеры",

                 font=dict(size=18))
    fig.update_layout({
    'plot_bgcolor': 'white',
    'paper_bgcolor': 'white',
    })
    fig.update_traces(textposition=improve_text_position(worlds['x']))
    fig.write_image(f'{i}.svg')

# %%
for i in list(data.area.unique()):
    df=data.loc[data.area==f'{i}']
    df.keyword=df.keyword.apply(lambda x: x if len(x)<16 else x.replace(' ','<br>'))
    draw_fig(df,i)
# Out:
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_6161/2143496144.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
